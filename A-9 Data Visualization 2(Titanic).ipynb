# %% [markdown]
# # DATA VISUALIZATION - II
#
# Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution
# of age with respect to each gender along with the information about whether they survived or
# not. (Column names : 'sex' and 'age')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='sex', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x=df.sex,y=df.age,hue=df.survived)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
def pieChart(df,categoricalColumn):
  plotNo = 1
  if df[categoricalColumn].dtype == 'O':
    plt.subplot(1, plotNo, plotNo)
    df[categoricalColumn].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plotNo+=1
    plt.plot()

# %%
df['sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
df['embarked'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='embarked'>

# %%
df['class'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='class'>

# %%
df['who'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='who'>

# %%
df['deck'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='deck'>

# %%
df['alive'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='alive'>

# %%
# Cluster Map
sns.clustermap(pd.crosstab(df['parch'],df['survived']))
